# %%
x = int(input())
c = 0
i = 1
while i <= x/2:
    if x%i == 0:
        c = c+1
    i = i +1
if c == 1:
    print("prime")
else:
    print("composite")
# Out:
#  9
# composite

# %%
x = [10,20,30,20,10,40]
y = []
for i in x:
    if i not in y:
        y.appendx[i]
print(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 5
#       3 for i in x:
#       4     if i not in y:
# ----> 5         y.appendx[i]
#       6 print(y)
#
# AttributeError: 'list' object has no attribute 'appendx'
