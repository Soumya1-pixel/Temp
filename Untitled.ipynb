# %%
x = int(input())
c = 0
i = 1
while i <= x/2:
    if x%i == 0:
        c = c+1
    i = i +1
if c == 1:
    print("prime")
else:
    print("composite")
# Out:
#  9
# composite

# %%
row = 5
for i in range(1,row+1):
    print("*" * i, e)
# Out:
# * ** *** **** *****
